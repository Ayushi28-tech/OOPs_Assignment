# %% [markdown]
# # Python OOPs Questions

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#
#  --> Object-Oriented Programming (OOP) is a programming paradigm that organizes and designs software around objects rather than functions or logic. These objects represent real-world entities and encapsulate data (attributes) and behavior (methods). OOP allows developers to create reusable, modular, and scalable code.

# %% [markdown]
# 2. What is a class in OOP?
#
#  --> A class in Object-Oriented Programming (OOP) is a blueprint or template used to create objects. It defines the attributes (data) and methods (functions) that the objects created from the class will have.
#
#  #Defining a class
#
#   class Person:
#
#         pass

# %% [markdown]
# 3. What is an object in OOP?
#
#  --> An object in Object-Oriented Programming (OOP) is an instance of a class. It represents a specific entity that has              attributes (data) and methods (functions) defined by its class.
#
#     Objects are the building blocks of an OOP-based program. They encapsulate both state (data) and behavior (actions), making       them key to modeling real-world entities in software.
#
# #Defining a class
#
# class Person:
#
#       pass
#
# c1 = Person()   # Create objects (instances of the Car class)

# %% [markdown]
# 4.  What is the difference between abstraction and encapsulation?
#
#  --> Abstraction:
#  #### Definition:
#
#   Abstraction focuses on hiding the implementation details and showing only the essential features of an object.
# It provides a simplified interface to interact with complex systems.
#
#  #### Purpose:
#  To reduce complexity and make the system easier to use.
#
#  #### Implementation:
#  Achieved through abstract classes, interfaces, and methods in OOP.
#
#  #### Example:
# from abc import ABC, abstractmethod
#
# class Shape(ABC):  # Abstract class
#
#     @abstractmethod
#     def area(self):
#         pass
#
# class Circle(Shape):
#
#     def __init__(self, radius):
#         self.radius = radius
#
#     def area(self):
#         return 3.14 * self.radius ** 2
#
# circle = Circle(5)
# print(circle.area())  # Output: 78.5

# %% [markdown]
#    --> Encapsulation:
#    #### Definition:
#    Encapsulation focuses on bundling data (attributes) and methods (functions) into a single unit (class) and restricting access    to certain components.
#    Protects data from being accessed or modified directly.
#
#    #### Purpose:
#    To secure the internal state of an object and promote modularity.
#
#    #### Implementation:
#    Achieved using access modifiers (private, protected, public) and getter/setter methods.
#
#    #### Example:
#    class BankAccount:
#
#     def __init__(self, balance):
#         self.__balance = balance  # Private attribute
#
#     def deposit(self, amount):
#         if amount > 0:
#             self.__balance += amount
#
#     def withdraw(self, amount):
#         if 0 < amount <= self.__balance:
#             self.__balance -= amount
#         else:
#             print("Invalid withdrawal amount")
#
#     def get_balance(self):  # Getter method
#         return self.__balance
#
# account = BankAccount(1000)
#
# account.deposit(500)
#
# account.withdraw(300)
#
# print(account.get_balance())  # Output: 1200

# %% [markdown]
# 5. What are dunder methods in Python?
#
#  --> Dunder methods (short for double underscore methods), also known as magic methods or special methods, are predefined methods in Python that have double underscores (__) at the beginning and end of their names. They provide a way to customize the behavior of Python objects and are commonly used to define how objects interact with built-in functions and operators.
#  #### Syntax:
#  Recognizable by their _ _dunder_ _naming style.

# %% [markdown]
# 6. Explain the concept of inheritance in OOP.
#
#   --> Inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows one class (the child class or subclass) to acquire the properties and methods of another class (the parent class or superclass). This promotes code reuse, modularity, and a hierarchical class structure.

# %% [markdown]
# 7. What is polymorphism in OOP?
#
#   --> Polymorphism is a fundamental concept in Object-Oriented Programming (OOP) that allows objects of different classes to be    treated as objects of a common parent class. The term "polymorphism" means "many forms", and in OOP, it refers to the ability    of a single function, method, or operator to work in different ways depending on the object it is applied to.
#
#   #### Example:
#
# class Circle:
#
#     def area(self):
#         return "Area of Circle"
#
# class Square:
#
#     def area(self):
#         return "Area of Square"
#
# shapes = [Circle(), Square()]
#
# for shape in shapes:
#
#     print(shape.area())  # Output: Area of Circle, Area of Square

# %% [markdown]
# 8. How is encapsulation achieved in Python?
#
#   --> Encapsulation in Python is the concept of restricting direct access to certain attributes and methods of a class to         protect the integrity of the data. It is achieved using access modifiers that define how class members (attributes and           methods) can be accessed.
#
#   ### Levels of Access Modifiers in Python
#   #### Public:
#
#    Accessible from anywhere (inside or outside the class).
#
#    Defined with no special syntax.
#
#    Example: self.name.
#
#   #### Protected:
#
#   Indicated with a single underscore (_).
#
#   Intended to be used within the class and its subclasses.
#
#   Not strictly enforced but acts as a convention.
#
#   #### Private:
#
#   Indicated with a double underscore (__).
#
#   Not directly accessible outside the class.
#
#   Implements name mangling to make it harder to access accidentally.

# %% [markdown]
# 9. What is a constructor in Python?
#
#   --> A constructor in Python is a special method used to initialize the attributes of a class when an object is created. The constructor method in Python is named __init__() and is called automatically when a new instance of a class is instantiated.
#
#   ### Syntax of a Constructor
#
#     class ClassName:
#
#         def __init__(self, parameters):
#              # Initialization code
#
#   ### Example:
#
#     class Person:
#
#         def __init__(self, name, age):  # Constructor
#              self.name = name  # Initializing instance variables
#              self.age = age
#
#         def display_info(self):
#              print(f"Name: {self.name}, Age: {self.age}")
#
#     #Creating an object of the Person class
#
#      person1 = Person("Alice", 30)
#
#      person1.display_info()  # Output: Name: Alice, Age: 30

# %% [markdown]
# 10. What are class and static methods in Python1
#
#   --> In Python, both class methods and static methods are special types of methods that differ from instance methods. They        belong to a class rather than an instance of the class, and their behavior depends on how they are defined and used.
#
#   #### Class Methods:
#     A class method is a method that is bound to the class and not the instance of the class. It can access or modify class-level     variables and is defined using the @classmethod decorator. The first parameter of a class method is cls, which represents       the class itself.
#
#   #### Example:
#
#      class MyClass:
#          class_variable = "Class Level Data"
#
#          @classmethod
#          def class_method(cls):
#              return f"Accessing: {cls.class_variable}"
#
#      print(MyClass.class_method())  # Output: Accessing: Class Level Data
#
#    #### Static Methods:
#      A static method is a method that does not depend on class or instance variables. It is defined using the @staticmethod          decorator. Static methods do not receive an implicit first argument like self or cls.
#
#    #### Example:
#
#        class MyClass:
#            @staticmethod
#            def static_method(a, b):
#            return a + b
#
#        print(MyClass.static_method(5, 10))  # Output: 15

# %% [markdown]
# 11. What is method overloading in Python?
#
#   --> Method overloading in object-oriented programming refers to the ability to define multiple methods in a class with the        same name but different numbers or types of parameters. It allows a method to perform different tasks based on the arguments    passed.
#
#   Python does not support traditional method overloading like some other programming languages (e.g., Java or C++). However,       Python achieves similar functionality through default arguments, variable-length arguments, and dynamic type checking.
#
#   #### Example:  Using Default Arguments
#
#      class Calculator:
#          def add(self, a, b=0, c=0):
#             return a + b + c
#
#      calc = Calculator()
#
#      print(calc.add(5))         # Output: 5
#
#      print(calc.add(5, 10))     # Output: 15
#
#      print(calc.add(5, 10, 15)) # Output: 30

# %% [markdown]
# 12. What is method overriding in OOP?
#
#   --> Method overriding is a feature in object-oriented programming where a subclass provides a specific implementation for a method that is already defined in its parent class. The overridden method in the subclass must have the same name, return type, and parameters as the method in the parent class.
#
#   #### Purpose of Method Overriding:
#
#   To provide a specialized or more specific behavior in a subclass.
#
#   To extend or modify the functionality of a parent class's method.
#
#   #### Example:
#
#       #Parent Class
#
#       class Animal:
#          def sound(self):
#              return "This animal makes a sound"
#
#       #Subclass
#
#       class Dog(Animal):
#          def sound(self):
#              return "The dog barks"
#
#       #Subclass
#
#       class Cat(Animal):
#          def sound(self):
#             return "The cat meows"
#
#       #Using Method Overriding
#
#       dog = Dog()
#
#       cat = Cat()
#
#       print(dog.sound())  # Output: The dog barks
#
#       print(cat.sound())  # Output: The cat meows

# %% [markdown]
# 13. What is a property decorator in Python?
#
#   --> The @property decorator in Python is a built-in decorator that allows you to define methods that can be accessed like attributes. It is primarily used to implement getters, setters, and deleters in a Pythonic way while maintaining encapsulation.
#
#   The @property decorator converts a method into a "getter" for an attribute. You can also define a corresponding "setter" or "deleter" using the @attribute_name.setter and @attribute_name.deleter decorators.
#
#   #### Example:
#
#     class Circle:
#         def __init__(self, radius):
#             self._radius = radius
#
#         @property
#         def radius(self):
#             return self._radius
#
#         @radius.setter
#         def radius(self, value):
#             if value < 0:
#                 raise ValueError("Radius cannot be negative")
#             self._radius = value
#
#         @radius.deleter
#         def radius(self):
#             print("Deleting radius")
#             del self._radius
#
#         circle = Circle(5)
#
#         print(circle.radius)  # Output: 5
#
#         circle.radius = 10    # Sets radius to 10
#
#         print(circle.radius)  # Output: 10
#
#         del circle.radius     # Deletes radius

# %% [markdown]
# 14. Why is polymorphism important in OOP?
#
#  --> Polymorphism is one of the four key principles of object-oriented programming (OOP), along with encapsulation, inheritance, and abstraction. It allows objects of different classes to be treated as objects of a common superclass. This is important because it enhances code flexibility, reusability, and maintainability.

# %% [markdown]
# 15. What is an abstract class in Python?
#
#  --> An abstract class in Python is a class that cannot be instantiated and is meant to serve as a blueprint for other classes. It often contains one or more abstract methods that are declared but not implemented in the abstract class itself. Subclasses of an abstract class must implement these abstract methods.
#
#   Python provides the abc (Abstract Base Class) module to define abstract classes and methods.
#
#   #### To define an abstract class:
#
#   Inherit from ABC.
#
#   Use the @abstractmethod decorator to declare abstract methods.
#
#   #### Example:
#
#       from abc import ABC, abstractmethod
#
#     class Animal(ABC):
#
#         @abstractmethod
#         def sound(self):
#             pass
#
#         @abstractmethod
#         def habitat(self):
#             pass

# %% [markdown]
# 16. What are the advantages of OOP?
#
#  --> Object-Oriented Programming (OOP) offers several benefits that make it a widely-used paradigm in software development. Below are the key advantages:
#
#  #### Modularity through Classes:
#  Code is organized into classes, which group related data (attributes) and behavior (methods) together.
#
#  This modular structure makes the code easier to read, understand, and maintain.
#
#  #### Reusability via Inheritance:
#  Inheritance allows you to create new classes based on existing ones.
#
#  Reduces redundancy by reusing existing code while extending or modifying behavior in derived classes.
#
#  #### Encapsulation for Security:
#  Encapsulation restricts access to certain parts of an object, exposing only necessary functionality through public methods.
#
#  Protects the internal state of objects and prevents unintended interference or misuse.
#
#  #### Abstraction for Simplification:
#  Abstraction hides complex implementation details and exposes only essential functionalities.
#
#  Helps in managing complexity and focusing on high-level design.
#
#  #### Polymorphism for Flexibility:
#  Polymorphism allows objects of different classes to be treated as objects of a common superclass.
#
#  Enables writing more generic and adaptable code, reducing dependencies on specific implementations.
#
#  #### Real-World Modeling:
#  OOP models real-world entities and their interactions, making the software more intuitive and aligned with natural thinking.
#
#  ### Example Highlighting OOP Advantages
#
#  #### Without OOP:
#      #Procedural approach
#
#      def calculate_circle_area(radius):
#         return 3.14 * radius * radius
#
#  #### With OOP:
#      #OOP approach
#
#      class Circle:
#         def __init__(self, radius):
#             self.radius = radius
#
#         def area(self):
#             return 3.14 * self.radius * self.radius
#
#  Encapsulation: radius is encapsulated within the Circle class.
#
#  Reusability: The Circle class can be reused in other programs.

# %% [markdown]
# 17.  What is the difference between a class variable and an instance variable?
#
#  --> Class variables and instance variables are two types of variables used to store data within a class. Their scope and usage differ significantly:
#
#  ### Class Variable:
#
#  #### Definition:
#  A variable that is shared among all instances of a class. It belongs to the class itself rather than any particular object.
#
#  #### Storage:
#  Stored in the class namespace.
#
#  #### Access:
#  Can be accessed using the class name or through an instance, but any change made through the class affects all instances.
#
#  #### Use Case:
#  Commonly used for constants or data shared by all instances.
#
#  #### Example:
#       class Employee:
#           company = "TechCorp"  # Class variable
#
#       #Access via class name
#
#       print(Employee.company)  # Output: TechCorp
#
#       #Access via instance
#
#       emp1 = Employee()
#
#       emp2 = Employ:ee()
#
#       print(emp1.company)  # Output: TechCorp
#
#       print(emp2.company)  # Output: TechCorp
#
#       #Modify class variable
#
#       Employee.company = "InnovateLtd"
#
#       print(emp1.company)  # Output: InnovateLtd
#
#       print(emp2.company)  # Output: InnovateLtd
#
#   ### Instance Variable:
#
#   #### Definition:
#   A variable that is unique to each instance of a class. It belongs to the instance (object) and is defined within the __init__   method or other instance methods.
#
#   ####  Storage:
#   Stored in the instance's namespace.
#
#   #### Access:
#   Accessed and modified only through the specific instance that owns it.
#
#   #### Use Case:
#   Used to store data unique to each object.
#
#   #### Example:
#       class Employee:
#         def __init__(self, name, salary):
#             self.name = name  # Instance variable
#             self.salary = salary  # Instance variable
#
#       emp1 = Employee("Alice", 50000)
#
#       emp2 = Employee("Bob", 60000)
#
#       #Access instance variables
#
#       print(emp1.name, emp1.salary)  # Output: Alice 50000
#
#       print(emp2.name, emp2.salary)  # Output: Bob 60000
#
#       #Modify instance variable
#
#       emp1.salary = 55000
#
#       print(emp1.salary)  # Output: 55000
#
#       print(emp2.salary)  # Output: 60000

# %% [markdown]
# 18. What is multiple inheritance in Python?
#
#  --> Multiple inheritance is a feature in Python where a class can inherit attributes and methods from more than one parent class. This allows a child class to combine the functionality of multiple parent classes.
#
#  #### Example:
#      class Animal:
#         def speak(self):
#             print("Animal makes a sound")
#
#      class Bird:
#         def fly(self):
#             print("Bird is flying")
#
#      class Bat(Animal, Bird):
#         pass
#
#      #Create an object of Bat
#
#      bat = Bat()
#
#      bat.speak()  # Output: Animal makes a sound
#
#      bat.fly()    # Output: Bird is flying

# %% [markdown]
# 19. Explain the purpose of ‘_ _ str_ _ ’ and ‘_ _ repr_ _ ’  methods in Python.
#
#  --> the _ _ _str_ _ _ and _ _ _repr_ _ _ methods are dunder methods (double underscore methods) used to define how an object should be represented as a string. They serve different purposes but are closely related.
#
#  ### _ _ repr_ _  Method:
#
#  #### Purpose:
#  Provides an official string representation of an object.
#
#  #### Goal:
#  The output of _ _ _repr_ _ _ should ideally be a string that can be used to recreate the object (when passed to eval()), or a      detailed description for developers.
#
#  #### Usage:
#  Called when using repr() or in interactive Python shells.
#
#  #### Example:
#
#     class Book:
#         def __init__(self, title, author):
#             self.title = title
#             self.author = author
#
#         def __repr__(self):
#             return f"Book(title='{self.title}', author='{self.author}')"
#
#     book = Book("1984", "George Orwell")
#
#     print(repr(book))  # Output: Book(title='1984', author='George Orwell')
#
#  ### _ _ str _ _ Method:
#
#  #### Purpose:
#  Provides a user-friendly string representation of an object.
#
#  #### Goal:
#  The output of _ _ _str_ _ _ should be readable and descriptive for end-users.
#
#  #### Usage:
#  Called when using str() or print() on an object.
#
#  #### Example:
#
#        class Book:
#           def __init__(self, title, author):
#              self.title = title
#              self.author = author
#
#           def __str__(self):
#              return f"{self.title} by {self.author}"
#
#        book = Book("1984", "George Orwell")
#
#        print(str(book))  # Output: 1984 by George Orwell

# %% [markdown]
# 20. What is the significance of the ‘super()’ function in Python?
#
#  --> The super() function in Python is used to call a method from the parent class (or superclass) in a child class. It plays a significant role in enabling inheritance, method overriding, and code reusability in object-oriented programming.
#
#  #### Example:
#
#      class Parent:
#         def greet(self):
#            print("Hello from Parent!")
#
#      class Child(Parent):
#         def greet(self):
#            super().greet()  # Call the parent class method
#            print("Hello from Child!")
#
#      #Using the Child class
#
#      child = Child()
#
#      child.greet()

# %% [markdown]
# 21. What is the significance of the _ _ _del_ _ _method in Python?
#
#  --> The _ _del_ _ method in Python is a special method, also known as a destructor, that is called when an object is about to be destroyed. It allows you to define cleanup actions, such as releasing resources or performing final operations, when the object is no longer needed.
#
#  #### Example:
#
#     class FileHandler:
#
#         def __init__(self, file_name):
#             self.file_name = file_name
#             self.file = open(file_name, 'w')
#             print(f"{self.file_name} opened.")
#
#         def __del__(self):
#             if self.file:
#                 self.file.close()
#                 print(f"{self.file_name} closed.")
#
#     #Creating and deleting the object
#
#     handler = FileHandler("example.txt")
#
#     del handler  # Explicitly delete the object

# %% [markdown]
# 22.  What is the difference between @staticmethod and @classmethod in Python?
#
#  --> Both @staticmethod and @classmethod are decorators in Python used to define methods that differ from regular instance methods. They allow methods to be called on the class itself rather than on an instance of the class. However, they serve different purposes and have distinct differences.
#
#  ### @staticmethod:
#
#  #### Definition:
#  A static method is a method that does not depend on the instance or class. It is defined using the @staticmethod decorator.
#
#  #### No Implicit Arguments:
#  Does not receive the self or cls arguments.
#
#  #### Purpose:
#  Used for utility functions that perform a task independently of the instance or class.
#
#  #### Access:
#  Cannot access or modify class or instance variables directly.
#
#  #### Example:
#
#      class MathUtils:
#          @staticmethod
#          def add(a, b):
#              return a + b
#
#      #Usage
#
#      print(MathUtils.add(10, 20))  # Output: 30
#
#  ### @classmethod:
#
#  #### Definition:
#  A class method is a method that operates on the class itself and is defined using the @classmethod decorator.
#
#  #### Receives cls as Argument:
#  Takes the class (cls) as its first implicit argument.
#
#  #### Purpose:
#  Used when a method needs to interact with or modify the class-level attributes or call other class methods.
#
#  #### Access:
#  Can access and modify class-level variables but not instance-specific data.
#
#  #### Example:
#       class Employee:
#          company_name = "TechCorp"
#          @classmethod
#          def change_company_name(cls, new_name):
#              cls.company_name = new_name
#
#      #Usage
#
#      print(Employee.company_name)  # Output: TechCorp
#
#      Employee.change_company_name("CodeCorp")
#
#      print(Employee.company_name)  # Output: CodeCorp

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance?
#
#  --> Polymorphism is a core concept of object-oriented programming (OOP) that allows objects of different classes to be treated as objects of a common parent class. It enables methods in a parent class to be overridden in child classes, allowing for dynamic method invocation based on the type of the object.
#
#  #### Example:
#
#       class Animal:
#           def speak(self):
#               return "I make a sound"
#
#       class Dog(Animal):
#           def speak(self):
#              return "Bark"
#
#       class Cat(Animal):
#           def speak(self):
#              return "Meow"
#
#       #Demonstrating polymorphism
#
#       animals = [Animal(), Dog(), Cat()]
#
#       for animal in animals:
#       print(animal.speak())

# %% [markdown]
# 24. What is method chaining in Python OOP?
#
#  --> Method chaining in Python Object-Oriented Programming (OOP) is a technique where multiple methods are called sequentially on the same object in a single statement. Each method returns the object itself (or another object), enabling the subsequent method calls.
#
#  #### Example:
#
#      class Calculator:
#         def __init__(self, value=0):
#             self.value = value
#
#         def add(self, amount):
#             self.value += amount
#             return self  # Returning self to enable chaining
#
#         def subtract(self, amount):
#             self.value -= amount
#             return self  # Returning self to enable chaining
#
#         def multiply(self, amount):
#             self.value *= amount
#             return self  # Returning self to enable chaining
#
#         def divide(self, amount):
#             if amount != 0:
#                 self.value /= amount
#             return self  # Returning self to enable chaining
#
#     #Using method chaining
#
#     calc = Calculator()
#
#     result = calc.add(10).subtract(5).multiply(2).divide(3).value
#
#     print("Final Result:", result)  # Output: Final Result: 3.3333333333333335

# %% [markdown]
# 25. What is the purpose of the _ _call_ _ method in Python?
#
#  --> The _ _call_ _ method in Python allows an instance of a class to be called as if it were a function. When the _ _call_ _ method is defined in a class, instances of that class become callable objects.
#
#  #### Example:
#      class Greeter:
#         def __init__(self, greeting):
#             self.greeting = greeting
#
#         def __call__(self, name):
#             return f"{self.greeting}, {name}!"
#
#      #Creating an instance
#
#      greeter = Greeter("Hello")
#
#      #Using the instance as a function
#
#      print(greeter("Alice"))  # Output: Hello, Alice!

# %% [markdown]
# # Practical Questions

# %%
#1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#that overrides the speak() method to print "Bark!".

class Animal:
    def speak(self):
        print("My name is Ayushi")
        
class Dog(Animal):
    def speak(self):
        print("Bark!")
        
obj = Dog()
obj.speak() # override the parent class
# Out:
# Bark!

# %%
#2.  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
#from it and implement the area() method in both.

import abc # module

class Shape:
    @abc.abstractmethod
    def calculate_area(self):
        print("Total Area")
        
class Circle(Shape):
    def calculate_area(self):
        return"Area of circle is pi*r**2"

class Rectangle(Shape):
    def calculate_area(self):
        return"Area of rectangle is length * breadth"

#To calculate the area of rectangle
rect = Rectangle()
rect.calculate_area()

#To calculate the area of circle
cir = Circle()
cir.calculate_area()
# Out:
# 'Area of circle is pi*r**2'

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:
    def vehicle_info(self):
        print("This is the vehicle class")
        
class Car(Vehicle):
    def car_info(self):
        print("This is the car class")
        
class ElectricCar(Car):
    def battery(self):
        print("This ElectricCar is run by battery")
        
# Creating instance of the derived classes 
elect = ElectricCar()
elect.battery()

elect.car_info()
elect.vehicle_info()
# Out:
# This ElectricCar is run by battery
# This is the car class
# This is the vehicle class

# %%
#4. same as number 3

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self,balance):
        self.__balance = balance
        
    def deposite(self,amount):
        self.__balance = self.__balance + amount
        
    def withdraw(self,amount):
        if self.__balance >= amount:
            self.__balance = self.__balance - amount
            return True
        else:
            return False
        
    def get_balance(self):
        return self.__balance
    
acc = BankAccount(1000)
acc.get_balance()

acc.deposite(500)
acc.get_balance()

acc.withdraw(100)
acc.get_balance()
# Out:
# 1400

# %%
#6.  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
#and Piano that implement their own version of play().

class Instrument:
    def play(self):
        print("Playing some instrument.")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar.")

class Piano(Instrument):
    def play(self):
        print("Playing the piano.")

# Demonstrating runtime polymorphism
def perform(instrument):
    instrument.play()

# Creating instances of the derived classes
guitar = Guitar()
piano = Piano()

# Calling the play method using polymorphism
perform(guitar) 
perform(piano)
# Out:
# Strumming the guitar.
# Playing the piano.

# %%
#7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
#method subtract_numbers() to subtract two numbers.

class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        """Class method to add two numbers."""
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        """Static method to subtract two numbers."""
        return a - b

# Using the class method and static method
result_add = MathOperations.add_numbers(10, 5)   # Class method call

result_subtract = MathOperations.subtract_numbers(10, 5)  # Static method call

print("Addition Result:", result_add)          
print("Subtraction Result:", result_subtract)
# Out:
# Addition Result: 15
# Subtraction Result: 5

# %%
#8.Implement a class Person with a class method to count the total number of persons created.

class Person:
    total_persons = 0
    def __init__(self, name):
        self.name = name
        Person.total_persons = Person.total_persons + 1
        
    @classmethod
    def get_total_persons(cls):
        return cls.total_persons

Person.total_persons # total number of persons count

per = Person("Ayushi")
per1 = Person("Ayu")

per.name
per1.name

Person.get_total_persons() # now total number of persons count by adding some person
# Out:
# 2

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        """Initialize numerator and denominator."""
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        """Override str() to display the fraction."""
        return f"{self.numerator}/{self.denominator}"

# Creating an instance of Fraction
fraction1 = Fraction(3, 4)
fraction2 = Fraction(7, 2)

# Printing the fraction
print(fraction1)  
print(fraction2)
# Out:
# 3/4
# 7/2

# %%
#10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

class Vector:
    def __init__(self, x, y):
        """Initialize vector with x and y components."""
        self.x = x
        self.y = y

    def __add__(self, other):
        """Override the + operator to add two vectors."""
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        raise TypeError("Operands must be instances of Vector")

    def __str__(self):
        """String representation of the vector."""
        return f"Vector({self.x}, {self.y})"

# Creating vector instances
vector1 = Vector(2, 3)
vector2 = Vector(4, 5)

# Adding vectors using the + operator
result = vector1 + vector2

# Displaying the result
print(result)
# Out:
# Vector(6, 8)

# %%
#11.Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is{name} and I am {age} years old."

class Person:
    def __init__(self, name, age):
        """Initialize the Person with name and age."""
        self.name = name
        self.age = age

    def greet(self):
        """Print a greeting message."""
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Creating an instance of Person
person1 = Person("Ayushi", 24)

# Calling the greet method
person1.greet()
# Out:
# Hello, my name is Ayushi and I am 24 years old.

# %%
#12.Implement a class Student with attributes name and grades. Create a method average_grade() to compute 
#the average of the grades.

class Student:
    def __init__(self, name, grades):
        """
        Initialize the Student with name and grades.
        :param name: str, name of the student
        :param grades: list of int or float, grades of the student
        """
        self.name = name
        self.grades = grades

    def average_grade(self):
        """
        Compute and return the average of the grades.
        :return: float, average grade
        """
        if self.grades:  # Ensure the list is not empty
            return sum(self.grades) / len(self.grades)
        return 0.0  # Return 0 if no grades are present

# Creating an instance of Student
student1 = Student("Ayushi Jaiswal", [85, 90, 78, 92, 88])

# Computing and displaying the average grade
average = student1.average_grade()
print(f"{student1.name}'s average grade is: {average:.2f}")
# Out:
# Ayushi Jaiswal's average grade is: 86.60

# %%
#13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
    def __init__(self):
        """Initialize the Rectangle with default dimensions."""
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        """
        Set the dimensions of the rectangle.
        """
        self.length = length
        self.width = width

    def area(self):
        """
        Calculate and return the area of the rectangle.
        :return: float, area of the rectangle
        """
        return self.length * self.width

# Using the Rectangle class
rect = Rectangle()

# Setting dimensions
rect.set_dimensions(5, 3)

# Calculating and displaying the area
print(f"The area of the rectangle is: {rect.area()}")
# Out:
# The area of the rectangle is: 15

# %%
#14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
#and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


# Creating instances of Employee and Manager
employee = Employee("Ayushi", 40, 20)
manager = Manager("Ayu", 40, 30, 500)

# Calculating and displaying salaries
print(f"{employee.name}'s salary: ${employee.calculate_salary():.2f}")  
print(f"{manager.name}'s salary: ${manager.calculate_salary():.2f}")
# Out:
# Ayushi's salary: $800.00
# Ayu's salary: $1700.00

# %%
#15.Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
#calculates the total price of the product.

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


# Example usage
product1 = Product("Laptop", 1000.00, 3)
product2 = Product("Phone", 500.00, 5)

# Calculating and displaying the total prices
print(f"Total price of {product1.name}: ${product1.total_price():.2f}")  
print(f"Total price of {product2.name}: ${product2.total_price():.2f}")
# Out:
# Total price of Laptop: $3000.00
# Total price of Phone: $2500.00

# %%
#16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
#implement the sound() method.

from abc import ABC, abstractmethod

# Abstract class Animal
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# Derived class Cow
class Cow(Animal):
    def sound(self):
        return "Moo"

# Derived class Sheep
class Sheep(Animal):
    def sound(self):
        return "Baa"

#creating instance
cow = Cow()
sheep = Sheep()

# Displaying the sounds made by the animals
print(f"Cow says: {cow.sound()}")  
print(f"Sheep says: {sheep.sound()}")
# Out:
# Cow says: Moo
# Sheep says: Baa

# %%
#17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
#returns a formatted string with the book's details.

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

# Example usage
book1 = Book("To Kill a Mockingbird", "Harper Lee", 1960)
book2 = Book("1984", "George Orwell", 1949)

# Getting and displaying the book information
print(book1.get_book_info())  
print(book2.get_book_info())
# Out:
# 'To Kill a Mockingbird' by Harper Lee, published in 1960
# '1984' by George Orwell, published in 1949

# %%
#18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
#attribute number_of_rooms.

# Base class House
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def get_details(self):
        return f"Address: {self.address}, Price: ${self.price}"

# Derived class Mansion
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)  # Initialize the parent class (House)
        self.number_of_rooms = number_of_rooms

    def get_details(self):
        return f"Address: {self.address}, Price: ${self.price}, Number of Rooms: {self.number_of_rooms}"

# Example usage
house = House("123 Oak Street", 250000)
mansion = Mansion("456 Luxury Lane", 1000000, 10)

# Displaying details
print(house.get_details())  
print(mansion.get_details())
# Out:
# Address: 123 Oak Street, Price: $250000
# Address: 456 Luxury Lane, Price: $1000000, Number of Rooms: 10
